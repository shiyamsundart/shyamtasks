# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Obesity Classification.csv')
df
# Out:
#       ID  Age  Gender  Height  Weight   BMI          Label
# 0      1   25    Male     175      80  25.3  Normal Weight
# 1      2   30  Female     160      60  22.5  Normal Weight
# 2      3   35    Male     180      90  27.3     Overweight
# 3      4   40  Female     150      50  20.0    Underweight
# 4      5   45    Male     190     100  31.2          Obese
# ..   ...  ...     ...     ...     ...   ...            ...
# 103  106   11    Male     175      10   3.9    Underweight
# 104  107   16  Female     160      10   3.9    Underweight
# 105  108   21    Male     180      15   5.6    Underweight
# 106  109   26  Female     150      15   5.6    Underweight
# 107  110   31    Male     190      20   8.3    Underweight
#
# [108 rows x 7 columns]

# %%
df.head()
# Out:
#    ID  Age  Gender  Height  Weight   BMI          Label
# 0   1   25    Male     175      80  25.3  Normal Weight
# 1   2   30  Female     160      60  22.5  Normal Weight
# 2   3   35    Male     180      90  27.3     Overweight
# 3   4   40  Female     150      50  20.0    Underweight
# 4   5   45    Male     190     100  31.2          Obese

# %%
df.tail()
# Out:
#       ID  Age  Gender  Height  Weight  BMI        Label
# 103  106   11    Male     175      10  3.9  Underweight
# 104  107   16  Female     160      10  3.9  Underweight
# 105  108   21    Male     180      15  5.6  Underweight
# 106  109   26  Female     150      15  5.6  Underweight
# 107  110   31    Male     190      20  8.3  Underweight

# %%
df.shape
# Out:
# (108, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      108 non-null    int64
#  1   Age     108 non-null    int64
#  2   Gender  108 non-null    object
#  3   Height  108 non-null    int64
#  4   Weight  108 non-null    int64
#  5   BMI     108 non-null    float64
#  6   Label   108 non-null    object
# dtypes: float64(1), int64(4), object(2)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#                ID         Age      Height      Weight         BMI
# count  108.000000  108.000000  108.000000  108.000000  108.000000
# mean    56.046296   46.555556  166.574074   59.490741   20.549074
# std     31.917939   24.720620   27.873615   28.856233    7.583818
# min      1.000000   11.000000  120.000000   10.000000    3.900000
# 25%     28.750000   27.000000  140.000000   35.000000   16.700000
# 50%     56.500000   42.500000  175.000000   55.000000   21.200000
# 75%     83.250000   59.250000  190.000000   85.000000   26.100000
# max    110.000000  112.000000  210.000000  120.000000   37.200000

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["Label"] = le.fit_transform(df["Label"])
df["Gender"] = le.fit_transform(df["Gender"])

# %%
df.Label.unique()
# Out:
# array([0, 2, 3, 1])

# %%
df.hist(figsize=(13,15))
# Out:
# array([[<AxesSubplot:title={'center':'ID'}>,
#         <AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Gender'}>],
#        [<AxesSubplot:title={'center':'Height'}>,
#         <AxesSubplot:title={'center':'Weight'}>,
#         <AxesSubplot:title={'center':'BMI'}>],
#        [<AxesSubplot:title={'center':'Label'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
sns.pairplot(df)

# %%
col=df.columns
print(col)
# Out:
# Index(['ID', 'Age', 'Gender', 'Height', 'Weight', 'BMI', 'Label'], dtype='object')

# %%
for i in col:
    sns.boxplot(df[i])
    plt.show()
# Out:
# /home/vectone/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/vectone/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/vectone/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/vectone/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/vectone/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/vectone/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/vectone/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
corrmat=df.corr()

# %%
sns.heatmap(corrmat,annot = True)
plt.show()

# %%
y = df["Label"]
y
# Out:
# 0      0
# 1      0
# 2      2
# 3      3
# 4      1
#       ..
# 103    3
# 104    3
# 105    3
# 106    3
# 107    3
# Name: Label, Length: 108, dtype: int64

# %%
x=df.drop(['Label','Gender'],axis =1)
x
# Out:
#       ID  Age  Height  Weight   BMI
# 0      1   25     175      80  25.3
# 1      2   30     160      60  22.5
# 2      3   35     180      90  27.3
# 3      4   40     150      50  20.0
# 4      5   45     190     100  31.2
# ..   ...  ...     ...     ...   ...
# 103  106   11     175      10   3.9
# 104  107   16     160      10   3.9
# 105  108   21     180      15   5.6
# 106  109   26     150      15   5.6
# 107  110   31     190      20   8.3
#
# [108 rows x 5 columns]

# %%
from sklearn.preprocessing import QuantileTransformer
quantile=QuantileTransformer()
X=quantile.fit_transform(x)
df_new=pd.DataFrame(X)
df_new.columns=['ID', 'Age', 'Height', 'Weight', 'BMI']
df_new
# Out:
# /home/vectone/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py:2590: UserWarning: n_quantiles (1000) is greater than the total number of samples (108). n_quantiles is set to n_samples.
#   warnings.warn(
#            ID       Age    Height    Weight       BMI
# 0    0.000000  0.214953  0.542056  0.728972  0.728972
# 1    0.009346  0.308411  0.425234  0.532710  0.532710
# 2    0.018692  0.392523  0.654206  0.836449  0.841121
# 3    0.028037  0.467290  0.322430  0.411215  0.411215
# 4    0.037383  0.542056  0.761682  0.911215  0.948598
# ..        ...       ...       ...       ...       ...
# 103  0.962617  0.000000  0.542056  0.000000  0.000000
# 104  0.971963  0.051402  0.425234  0.000000  0.000000
# 105  0.981308  0.135514  0.654206  0.037383  0.032710
# 106  0.990654  0.233645  0.322430  0.037383  0.032710
# 107  1.000000  0.322430  0.761682  0.079439  0.074766
#
# [108 rows x 5 columns]

# %%
col2 = df_new.columns
print(col2)
# Out:
# Index(['ID', 'Age', 'Height', 'Weight', 'BMI'], dtype='object')

# %%
for i in col2:
    sns.boxplot(df_new[i])
    plt.show()
# Out:
# /home/vectone/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/vectone/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/vectone/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/vectone/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/vectone/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df_new,y,test_size=0.2,random_state=0)

# %%
x_train.shape,y_train.shape
# Out:
# ((86, 5), (86,))

# %%
x_test.shape,y_test.shape
# Out:
# ((22, 5), (22,))

# %%
from sklearn.tree import DecisionTreeClassifier
tree=DecisionTreeClassifier()
tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=tree.predict(x_test)
y_pred.shape
print(y_pred.shape)
# Out:
# (22,)

# %%
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.metrics import f1_score,accuracy_score,precision_score,recall_score

# %%
print(f'accuracy: {accuracy_score(y_test,y_pred)}')
# Out:
# accuracy: 1.0

# %%
cm = confusion_matrix(y_test,y_pred)

# %%
sns.heatmap(cm,annot= True)
# Out:
# <AxesSubplot:>
